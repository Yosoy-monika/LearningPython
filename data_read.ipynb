# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as st
import pandas as pd

# %%
df= pd.read_csv('data.csv')
df
# Out:
#        0  1.41014
# 0     10  1.42946
# 1     20  1.42360
# 2     30  1.43008
# 3     40  1.42961
# 4     50  1.44085
# ..   ...      ...
# 95   960  1.43199
# 96   970  1.43528
# 97   980  1.43242
# 98   990  1.41756
# 99  1000  1.42287
#
# [100 rows x 2 columns]

# %%
plt.style.use('classic')
# %matplotlib inline
mu = np.mean(df['1.41014'] )   
sigma = np.std(df['1.41014']) 

plt.figure(figsize=(15,15))
n,bins,patches=plt.hist(df['1.41014'],bins=18,density=True)
plt.legend(["normal fit"],loc='upper right',prop={"size":21})
y = ((1 / (np.sqrt(2 * np.pi) * sigma)) * np.exp(-0.5* (1 / sigma * (bins - mu))**2))
plt.plot(bins,y, '--', c='r', linewidth =3)

plt.title("Histogram of Given Data")
plt.xlabel("Data points")
plt.ylabel("Height")
# Out:
# Text(0, 0.5, 'Height')
